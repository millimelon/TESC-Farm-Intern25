# %% [markdown]
# ### **1. Jupyter Notebook Basics**
# 1. **Create a New cell**:
#    - Open this Jupyter Notebook
#    - Add a markdown cell with your name and the people you are working with
#    - Add a code cell that prints "hello, im data farmer <your name> and im working with data farmer <people you are working with>"
#
# 2. **Keyboard Shortcuts**:
#    - Practice using Jupyter Notebook shortcuts:
#      - Add a new cell (`Esc` + `A` or `B`).
#      - Change a cell to markdown (`Esc` + `M`).
#      - Run a cell (`Shift` + `Enter`).
#
# 3. **Export the Notebook**:
#    - Export the notebook s a `.py` file and as an `.html` file.
#
# ---
#
# ### **2. Pandas Basics**
# 4. **Import Pandas**:
#    - Import the Pandas library and check its version.
#
# 5. **Create a DataFrame**:
#    - Create a DataFrame manually using a Python dictionary.
#    - Example:
#      ```python
#      data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Los Angeles', 'Chicago']}
#      df = pd.DataFrame(data)
#      ```
#
# 6. **Read and Write Data**:
#    - Read soil_data.csv file into a data frame and display the first 5 rows.
#    - Save the DataFrame to a new CSV file output.csv
#
# ---
#
# ### **3. Data Exploration**
# 7. **Inspect Data**:
#    - Display the middle row and the last 3 rows of the DataFrame.
#    - Check the number of rows and columns using `.shape`.
#    - Get summary statistics using `.describe()`.
#
# 8. **Data Types**:
#    - Check the data types of each column using `.dtypes`.
#    - Convert a column to a different data type (e.g., string to integer).
#
# 9. **Missing Data**:
#    - Check for missing values using `.isnull()`. # what does this result mean?
#    - Fill missing values with a specific value (e.g., 0 or the mean).
# ---
#
# ### **4. Data Manipulation**
# 10. **Filtering Data**:
#     - Filter rows where a specific condition is met (e.g., `N > 70`). n is nitrogen
#     - Use `.loc[]` and `.iloc[]` to select specific rows and columns.
#
# 11. **Sorting Data**:
#     - Sort the DataFrame by a specific column (e.g., `ph` in descending order).
#
# 12. **Adding/Removing Columns**:
#     - Add a new column to the DataFrame (e.g., `nitrogen needed`). # we could build a predictor to determine if the crops need nitrogen but this is boring so we won't be doing it today.
#     - Drop a column from the DataFrame. drop 'nitrogen needed' column
#
# 13. **Grouping Data**:
#     - Group the DataFrame by a specific column and calculate aggregate statistics (mean, sum and median).
#
# ---
#
# ### **5. Advanced Operations** do not worry about finishing this next section you are prepared for the lab if you have completed the previous sections.
# 14. **Merging DataFrames**:
#     - Create two DataFrames and merge them on a common column (e.g., `ID`).
#
# 15. **Pivot Tables**:
#     - Create a pivot table to summarize data (e.g., average `Age` by `City`).
#
# 16. **Apply Functions**:
#     - Use `.apply()` to apply a custom function to a column (e.g., convert all names to uppercase).
#
# 17. **Handling Duplicates**:
#     - Identify and remove duplicate rows from the DataFrame.
#
# ---
#
# ### **6. Visualization (Optional)**
# 18. **Basic Plotting**:
#     - Use Pandas' built-in plotting functions to create visualizations (e.g., bar plot, histogram).
#
# 19. **Export Plots**:
#     - Save a plot as an image file (e.g., `.png`).
#
# ---
